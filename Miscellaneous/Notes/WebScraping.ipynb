# %%
import urllib
from bs4 import BeautifulSoup 

import pandas as pd
ser = pd.Series([100, 200, 300, 400, 500], index = ['tom', 'bob', 'nancy', 'dan', 'eric'])

# %%
ser.loc[['tom', 'bob']]
# Out:
# tom    100
# bob    200
# dtype: int64

# %%
ser.iloc[[0,1]]
# Out:
# tom    100
# bob    200
# dtype: int64

# %%
ser[[0,1]]
# Out:
# tom    100
# bob    200
# dtype: int64

# %%
ser[['tom', 'bob']]
# Out:
# tom    100
# bob    200
# dtype: int64

# %%
import requests

page = requests.get("https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of state and union territory capitals in India - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_state_and_union_territory_capitals_in_India","wgTitle":"List of state and union territory capitals in India","wgCurRevisionId":807184174,"wgRevisionId":807184174,"wgArticleId":2371868,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia pending changes protected pages (level 1)","Featured lists","States and territories of India-related lists","Indian capital cities","Lists of cities in India","Lists of capitals of country su
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of state and union territory capitals in India - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
soup.find_all('p')
# Out:
# [<p><a href="/wiki/India" title="India">India</a> is a country located in southern Asia. With <a href="/wiki/Demographics_of_India" title="Demographics of India">over 1.3 billion people</a>, India is the most populous <a href="/wiki/Democracy" title="Democracy">democracy</a> in the world. It is a <a href="/wiki/Federalism" title="Federalism">federal</a> <a class="mw-redirect" href="/wiki/Constitutional_republic" title="Constitutional republic">constitutional republic</a> governed under a <a href="/wiki/Parliamentary_system" title="Parliamentary system">parliamentary system</a> consisting of <a class="mw-redirect" href="/wiki/States_and_territories_of_India" title="States and territories of India">29 states and 7 union territories</a>.<sup class="reference" id="cite_ref-FOOTNOTELibrary_of_Congress2004_1-0"><a href="#cite_note-FOOTNOTELibrary_of_Congress2004-1">[1]</a></sup> All states, as well as the union territories of <a href="/wiki/Puducherry" title="Puducherry">Puducherry</a> and
# ...

# %%
soup.find_all('p')[0].get_text()
# Out:
# 'India is a country located in southern Asia. With over 1.3 billion people, India is the most populous democracy in the world. It is a federal constitutional republic governed under a parliamentary system consisting of 29 states and 7 union territories.[1] All states, as well as the union territories of Puducherry and the National Capital Territory of Delhi, have elected legislatures and governments, both patterned on the Westminster model. The remaining five union territories are directly ruled by the centre through appointed administrators. In 1956, under the States Reorganisation Act, states were reorganised on a linguistic basis.[2] Since then, their structure has remained largely unchanged. Each state or union territory is further divided into administrative districts.'

# %%
soup.find_all('a', class_='mw-redirect')
# Out:
# [<a class="mw-redirect" href="/wiki/List_of_states_and_territories_of_India_by_area" title="List of states and territories of India by area">Area</a>,
#  <a class="mw-redirect" href="/wiki/List_of_Indian_states_by_GDP_per_capita" title="List of Indian states by GDP per capita">per capita</a>,
#  <a class="mw-redirect" href="/wiki/Constitutional_republic" title="Constitutional republic">constitutional republic</a>,
#  <a class="mw-redirect" href="/wiki/States_and_territories_of_India" title="States and territories of India">29 states and 7 union territories</a>,
#  <a class="mw-redirect" href="/wiki/National_Capital_Territory_of_Delhi" title="National Capital Territory of Delhi">National Capital Territory of Delhi</a>,
#  <a class="mw-redirect" href="/wiki/States_Reorganisation_Act" title="States Reorganisation Act">States Reorganisation Act</a>,
#  <a class="mw-redirect" href="/wiki/High_Courts_of_India" title="High Courts of India">High Courts</a>,
# ...

# %%
soup.select('body p a')
# Out:
# [<a href="/wiki/India" title="India">India</a>,
#  <a href="/wiki/Demographics_of_India" title="Demographics of India">over 1.3 billion people</a>,
#  <a href="/wiki/Democracy" title="Democracy">democracy</a>,
#  <a href="/wiki/Federalism" title="Federalism">federal</a>,
#  <a class="mw-redirect" href="/wiki/Constitutional_republic" title="Constitutional republic">constitutional republic</a>,
#  <a href="/wiki/Parliamentary_system" title="Parliamentary system">parliamentary system</a>,
#  <a class="mw-redirect" href="/wiki/States_and_territories_of_India" title="States and territories of India">29 states and 7 union territories</a>,
#  <a href="#cite_note-FOOTNOTELibrary_of_Congress2004-1">[1]</a>,
#  <a href="/wiki/Puducherry" title="Puducherry">Puducherry</a>,
#  <a class="mw-redirect" href="/wiki/National_Capital_Territory_of_Delhi" title="National Capital Territory of Delhi">National Capital Territory of Delhi</a>,
# ...

# %%
[i for i in soup.select('body p a')
# Out:
# [<a href="/wiki/India" title="India">India</a>,
#  <a href="/wiki/Demographics_of_India" title="Demographics of India">over 1.3 billion people</a>,
#  <a href="/wiki/Democracy" title="Democracy">democracy</a>,
#  <a href="/wiki/Federalism" title="Federalism">federal</a>,
#  <a class="mw-redirect" href="/wiki/Constitutional_republic" title="Constitutional republic">constitutional republic</a>,
#  <a href="/wiki/Parliamentary_system" title="Parliamentary system">parliamentary system</a>,
#  <a class="mw-redirect" href="/wiki/States_and_territories_of_India" title="States and territories of India">29 states and 7 union territories</a>,
#  <a href="#cite_note-FOOTNOTELibrary_of_Congress2004-1">[1]</a>,
#  <a href="/wiki/Puducherry" title="Puducherry">Puducherry</a>,
#  <a class="mw-redirect" href="/wiki/National_Capital_Territory_of_Delhi" title="National Capital Territory of Delhi">National Capital Territory of Delhi</a>,
# ...
