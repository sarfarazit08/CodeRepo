# %% [markdown]
# R Code pulled from https://www.statmethods.net/advgraphs/ggplot2.html

# %%
# ggplot2 examples
library(ggplot2)

# %%
# create factors with value labels 
mtcars$gear <- factor(mtcars$gear,levels=c(3,4,5),
  	labels=c("3gears","4gears","5gears")) 
mtcars$am <- factor(mtcars$am,levels=c(0,1),
  	labels=c("Automatic","Manual")) 
mtcars$cyl <- factor(mtcars$cyl,levels=c(4,6,8),
   labels=c("4cyl","6cyl","8cyl"))

# %%
# Kernel density plots for mpg
# grouped by number of gears (indicated by color)
qplot(mpg, data=mtcars, geom="density", fill=gear, alpha=I(.5), 
   main="Distribution of Gas Milage", xlab="Miles Per Gallon", 
   ylab="Density")
# Out:
# plot without title

# %%
# Scatterplot of mpg vs. hp for each combination of gears and cylinders
# in each facet, transmittion type is represented by shape and color
qplot(hp, mpg, data=mtcars, shape=am, color=am, 
   facets=gear~cyl, size=I(3),
   xlab="Horsepower", ylab="Miles per Gallon")
# Out:
# plot without title

# %%
# Separate regressions of mpg on weight for each number of cylinders
qplot(wt, mpg, data=mtcars, geom=c("point", "smooth"), 
   method="lm", formula=y~x, color=cyl, 
   main="Regression of MPG on Weight", 
   xlab="Weight", ylab="Miles per Gallon")
# Out:
# Warning message:
# “Ignoring unknown parameters: method, formula”
# plot without title

# %%
# Boxplots of mpg by number of gears 
# observations (points) are overlayed and jittered
qplot(gear, mpg, data=mtcars, geom=c("boxplot", "jitter"), 
   fill=gear, main="Mileage by Gear Number",
   xlab="", ylab="Miles per Gallon")
# Out:
# plot without title

# %%
x = seq(-4,4,0.2)
y = 2*x^2 + 4*x

# %%
plot(x, y, pch = 16,col ="red")
# Out:
# plot without title

# %%
plot(x, y, pch = 16,col ="red", xlim =c(-8,8), ylim =c(-20,50), main = "Plot", xlab ="X variable ", ylab = "Y variable") 
lines(x,y)
# Out:
# Plot with title “Plot”

# %%
plot(x, y, pch = 16,col ="red", xlim =c(-8,8), ylim =c(-20,50), main = "Plot", xlab ="X variable ", ylab = "Y variable") 
rug(x)
# Out:
# Plot with title “Plot”

# %%
x = c(1,2,3,6) 
y = c(1,3,4,5) 
plot(x, y, pch = 16,col ="red", xlim =c(-8,8), ylim =c(-20,50), main = "Plot", xlab ="X variable ", ylab = "Y variable") 
rug(y)
# Out:
# Plot with title “Plot”

# %%
x = c(1,2,3,6) 
y = c(1,3,4,5) 
plot(x, y, pch = 16,col ="red", xlim =c(-8,8), ylim =c(-20,50), main = "Plot", xlab ="X variable ", ylab = "Y variable") 
rug(y) 
lines(x, y)
# Out:
# Plot with title “Plot”

# %%
colors() [c(1, 2, 3,10) ]
# Out:
# [1] "white"        "aliceblue"    "antiquewhite" "aquamarine2"

# %%
x = c(1,2,3,6) 
y = c(1,3,4,5) 
plot(x, y, pch = 16,col ="red", xlim =c(-8,8), ylim =c(-20,50), main = "Plot", xlab ="X variable ", ylab = "Y variable") 
rug(y) 
abline(lm(y ~ x) ) #place a space before and after ~
# Out:
# Plot with title “Plot”

# %%
curve(5*x^3 + 6*x^2 - 5, - 2,2,col="blue",main="Cubic Curve")
# Out:
# Plot with title “Cubic Curve”

# %%
x = seq(-pi, pi, length=50)
y = sin(x) 

plot(x, y, pch=17,cex=.7,col="darkgreen")
lines(x, y, col="darkgreen")
# Out:
# plot without title

# %%
x= c(1,2,3,4,5,6,7) 
y1=c(2,4,5,7,8,9,12) 
y2=c(3,5,2,4,7,6,8) 
plot(x, y1, pch=17,cex=.7,col="darkgreen", type="o" )
lines(y2, pch=17,cex=.7,col="red",type="o",  lty=2)
# Out:
# plot without title

# %%
x= c(1,2,3,4,5,6,7) 
y1=c(2,4,5,7,8,9,12) 
y2=c(3,5,2,4,7,6,8) 
plot(x, y1, pch=16,cex=.7,col="blue", type="o" )
lines(y2, pch=17,cex=.7,col="red",type="o",  lty=2)
legend(1,c(12), c("y1", "y2"), cex=.7, col=c("blue", "red"), pch=c(16,17), lty=1:2)
# Out:
# plot without title

# %%
x= c(1,2,3,4,5,6,7) 
y1=c(2,4,5,7,8,9,12) 
y2=c(3,5,2,4,7,6,8) 
y3=c(4,6,7,5,2,3,8)
y4=c(6,2,3,3,5,6,7) 
plot(x, y1, pch=1,cex=.7,col="blue", type="o" )
plot(x, y2, pch=2,cex=.7,col="blue", type="o" )
plot(x, y3, pch=15,cex=.7,col="blue", type="o" )
plot(x, y4, pch=16,cex=.7,col="blue", type="o" )
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
x= c(1,2,3,4,5,6,7) 
y1=c(2,4,5,7,8,9,12) 
y2=c(3,5,2,4,7,6,8) 
y3=c(4,6,7,5,2,3,8)
y4=c(6,2,3,3,5,6,7)
par(mfrow=c(2,2))
plot(x, y1, pch=1,cex=.7,col="blue", type="o" )
plot(x, y2, pch=2,cex=.7,col="blue", type="o" )
plot(x, y3, pch=15,cex=.7,col="blue", type="o" )
plot(x, y4, pch=16,cex=.7,col="blue", type="o" )
# Out:
# plot without title
